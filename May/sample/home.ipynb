# %%
import pandas as p
import matplotlib.pyplot as plt
pd=p.read_csv('data.csv')
pd['CO2'].plot()
# Out:
# <Axes: >

# %%
#scatter() - x=Volume,y=CO2
pd.plot(kind='scatter',x='Volume',y='CO2')
plt.show()

# %%
pd.plot(x='Volume',y='CO2')
plt.show()

# %%
pd['CO2'],pd['Volume'].plot()
# Out:
# (0      99
#  1      95
#  2      95
#  3      90
#  4     105
#  5     105
#  6      90
#  7      92
#  8      98
#  9      99
#  10     99
#  11    101
#  12     99
#  13     94
#  14     97
#  15     97
#  16     99
#  17    104
#  18    104
#  19    105
#  20     94
#  21     99
#  22     99
#  23     99
#  24     99
#  25    102
#  26    104
#  27    114
#  28    109
#  29    114
#  30    115
#  31    117
#  32    104
#  33    108
#  34    109
#  35    120
#  Name: CO2, dtype: int64,
#  <Axes: >)

# %%
pd.columns
# Out:
# Index(['Car', 'Model', 'Volume', 'Weight', 'CO2'], dtype='object')
